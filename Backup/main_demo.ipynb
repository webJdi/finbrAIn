# %%
import os
import sys
sys.path.append('src')

from dotenv import load_dotenv
load_dotenv()

from src.agents.research_agent import InvestmentResearchAgent
from src.workflows.prompt_chaining import PromptChainingWorkflow
from src.workflows.routing import RoutingWorkflow
from src.workflows.evaluator_optimizer import EvaluatorOptimizerWorkflow
from src.utils.config import FinancialAgentConfig

print("Financial Agentic AI System - Demo")
print("===================================")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 8
#       5 from dotenv import load_dotenv
#       6 load_dotenv()
# ----> 8 from src.agents.research_agent import InvestmentResearchAgent
#       9 from src.workflows.prompt_chaining import PromptChainingWorkflow
#      10 from src.workflows.routing import RoutingWorkflow
#
# ModuleNotFoundError: No module named 'src'
